# %% [markdown]
# # <font color=red> _Liverpool Football Club and Steven Gerrard_
#
# ### A comparison of the Liverpool's challenging years (2008-2016) to that of their title rivals (Chelsea and Manchester United) and a look at Fifa's evaluation of Steven Gerrard and his english midfield rival Frank Lampard of Chelsea

# %% [markdown]
# ## Background
#
# This report will examine aspects of what is considered an unremarkable, if not difficult, time period for Liverpool Football Club (often referred to as LFC or LIV) and their legendary captain Steven Gerrard. The data utilized for this report ranges from the 2008-2009 season up to the 2015-2016 season. LFC came close on many occasions, but only featured limited team success, especially for such a historically decorated and respected English club. In fact, their only major trophy was a 2011-12 English Football League Cup (Carling Cup) victory over Cardiff Cup.
#
# This period saw five different managers, starting with the ending of who was then the most prolific manager of Liverpool's modern era (Rafael Benítez) and the start of a future Anfield legend's time with the Reds (Jurgen Klopp). These two bookend the horrible 7 months of Roy Hodgson, the second attempt as manager for Kenny Dalglish and the somewhat better results of Brendan Rodgers. Dalglish was at least able to bring one domestic cup victory and near success in the English Premier League(EPL).
#
# It is hard to not speak of this time period without a negative bias. Fans watched a European Champions League winning squad slowly dissipate into something that was held together by Steven Gerrard alone for several years, at least until the financial investment during Brendan Rodgers reign. Though, despite the investment, and an unexpected title run, Brendan Rodgers time with Liverpool ended unremarkably. This is not to say that fans lost hope, but it was a bleak time.
#
# How did the club really perform compared to its title rivals? Was Steven Gearrard considered better or worse than Frank Lampard based on Fifa's analysis? This report will aim to provide those comparisons in a clear digestible manner.
#
# Regardless, all you Reds know how to carry on...![alt text](Miles/Dropbox/Udacity/2020/Data_Analyst/introduction_to_data_analysis/final_project_football_data/investigate-a-dataset-template.ipynb/liverpool-fc.jpg "Liverpool Crest")
#
# <em>When you walk through a storm
# Hold your head up high
# And don't be afraid of the dark
#
# At the end of a storm
# There's a golden sky
# And the sweet silver song of a lark
#
# Walk on through the wind
# Walk on through the rain
# Though your dreams be tossed and blown
#
# Walk on, walk on
# With hope in your heart
# And you'll never walk alone</em>

# %%
#import relevant/required modules and import csv data required for the report
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

all_liv_matches = pd.read_csv('liverpool_matches.csv')
all_chel_matches = pd.read_csv('chelsea_matches.csv')
all_man_u_matches = pd.read_csv('man_u_matches.csv')
gerrard_attributes = pd.read_csv('gerrard_attributes.csv')
lampard_attributes = pd.read_csv('lampard_attributes.csv')

# %%
all_liv_matches.head()
# Out:
#    home_team_goal  away_team_goal  away_team_api_id  home_team_api_id  \
# 0               0               1              8650              8472
# 1               1               0              8462              8650
# 2               2               1              8650              8586
# 3               3               0              8659              8650
# 4               0               2              8650              8559
#
#            home_team     season                 date
# 0         Sunderland  2008/2009  2008-08-16 00:00:00
# 1          Liverpool  2008/2009  2008-10-29 00:00:00
# 2  Tottenham Hotspur  2008/2009  2008-11-01 00:00:00
# 3          Liverpool  2008/2009  2008-11-08 00:00:00
# 4   Bolton Wanderers  2008/2009  2008-11-15 00:00:00

# %%
all_liv_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   home_team_goal    304 non-null    int64
#  1   away_team_goal    304 non-null    int64
#  2   away_team_api_id  304 non-null    int64
#  3   home_team_api_id  304 non-null    int64
#  4   home_team         304 non-null    object
#  5   season            304 non-null    object
#  6   date              304 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 16.8+ KB

# %%
all_liv_matches['result'] = all_liv_matches['home_team_goal'] - all_liv_matches['away_team_goal']
all_liv_matches.head()
# Out:
#    home_team_goal  away_team_goal  away_team_api_id  home_team_api_id  \
# 0               0               1              8650              8472
# 1               1               0              8462              8650
# 2               2               1              8650              8586
# 3               3               0              8659              8650
# 4               0               2              8650              8559
#
#            home_team     season                 date  result
# 0         Sunderland  2008/2009  2008-08-16 00:00:00      -1
# 1          Liverpool  2008/2009  2008-10-29 00:00:00       1
# 2  Tottenham Hotspur  2008/2009  2008-11-01 00:00:00       1
# 3          Liverpool  2008/2009  2008-11-08 00:00:00       3
# 4   Bolton Wanderers  2008/2009  2008-11-15 00:00:00      -2

# %%
home_games = all_liv_matches[all_liv_matches['home_team'] == "Liverpool"]
home_games.head(10)
# Out:
#     home_team_goal  away_team_goal  away_team_api_id  home_team_api_id  \
# 1                1               0              8462              8650
# 3                3               0              8659              8650
# 5                0               0              9879              8650
# 6                0               0              8654              8650
# 8                2               2              8667              8650
# 10               3               0              8559              8650
# 11               2               1              8549              8650
# 14               1               1              8668              8650
# 16               2               0              8455              8650
# 18               1               1              8456              8650
#
#     home_team     season                 date  result
# 1   Liverpool  2008/2009  2008-10-29 00:00:00       1
# 3   Liverpool  2008/2009  2008-11-08 00:00:00       3
# ...

# %%
away_games = all_liv_matches[all_liv_matches['home_team'] != "Liverpool"]
away_games.head(10)
# Out:
#     home_team_goal  away_team_goal  away_team_api_id  home_team_api_id  \
# 0                0               1              8650              8472
# 2                2               1              8650              8586
# 4                0               2              8650              8559
# 7                1               3              8650              8655
# 9                1               1              8650              9825
# 12               1               5              8650             10261
# 13               0               0              8650             10194
# 15               1               1              8650              8528
# 17               2               3              8650              8462
# 19               2               0              8650              8549
#
#             home_team     season                 date  result
# 0          Sunderland  2008/2009  2008-08-16 00:00:00      -1
# 2   Tottenham Hotspur  2008/2009  2008-11-01 00:00:00       1
# ...

# %%
h_win_loss_draw = []

for r in home_games['result']:
    if r > 0:
        h_win_loss_draw.append('W')
    elif r < 0:
        h_win_loss_draw.append('L')
    elif r == 0:
        h_win_loss_draw.append('D/T')

home_games['win_loss_draw'] = h_win_loss_draw
home_games.head()
# Out:
# C:\Users\Miles\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#    home_team_goal  away_team_goal  away_team_api_id  home_team_api_id  \
# 1               1               0              8462              8650
# 3               3               0              8659              8650
# 5               0               0              9879              8650
# 6               0               0              8654              8650
# 8               2               2              8667              8650
#
#    home_team     season                 date  result win_loss_draw
# 1  Liverpool  2008/2009  2008-10-29 00:00:00       1             W
# ...

# %%
a_win_loss_draw = []

for r in away_games['result']:
    if r > 0:
        a_win_loss_draw.append('L')
    elif r < 0:
        a_win_loss_draw.append('W')
    elif r == 0:
        a_win_loss_draw.append('D/T')
        
away_games['win_loss_draw'] = a_win_loss_draw
away_games.head()
# Out:
# C:\Users\Miles\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#    home_team_goal  away_team_goal  away_team_api_id  home_team_api_id  \
# 0               0               1              8650              8472
# 2               2               1              8650              8586
# 4               0               2              8650              8559
# 7               1               3              8650              8655
# 9               1               1              8650              9825
#
#            home_team     season                 date  result win_loss_draw
# ...

# %%
home_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 1 to 301
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   home_team_goal    152 non-null    int64
#  1   away_team_goal    152 non-null    int64
#  2   away_team_api_id  152 non-null    int64
#  3   home_team_api_id  152 non-null    int64
#  4   home_team         152 non-null    object
#  5   season            152 non-null    object
#  6   date              152 non-null    object
#  7   result            152 non-null    int64
#  8   win_loss_draw     152 non-null    object
# dtypes: int64(5), object(4)
# memory usage: 11.9+ KB

# %%
merge_attempt = pd.concat([home_games, away_games], axis=0)

# %%
merge_attempt
# Out:
#      home_team_goal  away_team_goal  away_team_api_id  home_team_api_id  \
# 1                 1               0              8462              8650
# 3                 3               0              8659              8650
# 5                 0               0              9879              8650
# 6                 0               0              8654              8650
# 8                 2               2              8667              8650
# ..              ...             ...               ...               ...
# 295               3               1              8650             10003
# 297               1               1              8650              8659
# 299               3               1              8650             10260
# 302               1               1              8650              8668
# 303               0               0              8650              8586
#
#                 home_team     season                 date  result  \
# ...

# %%
merge_attempt.sort_values('date', axis=0)
# Out:
#      home_team_goal  away_team_goal  away_team_api_id  home_team_api_id  \
# 0                 0               1              8650              8472
# 11                2               1              8549              8650
# 22                0               0              8650             10252
# 32                2               1             10260              8650
# 33                0               0             10194              8650
# ..              ...             ...               ...               ...
# 294               2               2             10261              8650
# 295               3               1              8650             10003
# 296               2               0              9817              8650
# 289               1               1              8455              8650
# 297               1               1              8650              8659
#
#                 home_team     season                 date  result  \
# ...

# %%
merge_attempt.hist();

# %%
season_results = merge_attempt.groupby('season')['win_loss_draw'].value_counts()

# %%
season_results.head()
# Out:
# season     win_loss_draw
# 2008/2009  W                25
#            D/T              11
#            L                 2
# 2009/2010  W                18
#            L                11
# Name: win_loss_draw, dtype: int64

# %%
season_results2 = pd.crosstab(merge_attempt['season'], merge_attempt['win_loss_draw'])
season_results2
# Out:
# win_loss_draw  D/T   L   W
# season
# 2008/2009       11   2  25
# 2009/2010        9  11  18
# 2010/2011        7  14  17
# 2011/2012       10  14  14
# 2012/2013       13   9  16
# 2013/2014        6   6  26
# 2014/2015        8  12  18
# 2015/2016       12  10  16

# %%
season_results2.plot.bar();

# %% [markdown]
# ## Gerrard Versus Lampard
#
# That was one of "The" battles for many years in the EPL and on the English national team. Which of these two midfield greats was the best in England, Europe, the world? Well, the data we are working with covers both of them over the later years of their career, but unfortunately is a collection of FIFA attribute rankings, rather than true statistics. These rankings are not the best way to examine the career, let alone compare, these prolific midfielders, but we are atleast able to understand who was <em>assessed</em> as having the most potential and being the best overall player on a year by year basis.
